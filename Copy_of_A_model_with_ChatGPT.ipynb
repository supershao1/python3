# %% [markdown]
# <a href="https://colab.research.google.com/github/supershao1/python3/blob/master/Copy_of_A_model_with_ChatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

# load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# normalize the pixel values (0-255) to be between 0 and 1
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# define the model architecture
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# compile the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

X_val = X_test[:2000]
y_val = y_test[:2000]
X_test = X_test[2000:]
y_test = y_test[2000:]

# train the model
history = model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1356 - accuracy: 0.9593 - val_loss: 0.0781 - val_accuracy: 0.9770
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0543 - accuracy: 0.9838 - val_loss: 0.0695 - val_accuracy: 0.9770
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0401 - accuracy: 0.9881 - val_loss: 0.0659 - val_accuracy: 0.9815
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0319 - accuracy: 0.9907 - val_loss: 0.0735 - val_accuracy: 0.9795
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0270 - accuracy: 0.9926 - val_loss: 0.0826 - val_accuracy: 0.9810
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.0837 - val_accuracy: 0.9805
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 0.1034 - val_accuracy: 0.9805
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.0742 - val_accuracy: 0.9825
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 0.0744 - val_accuracy: 0.9845
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.1071 - val_accuracy: 0.9805

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0578 - accuracy: 0.9871
# Test accuracy: 0.9871249794960022

# %%
# plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Select 20 random indexes from the train set
random_indices = np.random.randint(0, len(X_train), 20)

# Extract the 20 random images and labels from the train set
random_images = X_train[random_indices]
random_labels = y_train[random_indices]

# Plot the 20 random images
fig, axes = plt.subplots(4, 5, figsize=(10, 8))
axes = axes.ravel()

for i, ax in enumerate(axes):
    ax.imshow(random_images[i], cmap="gray")
    ax.axis('off')
    ax.set_title(str(random_labels[i]))

plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  flatten_5 (Flatten)         (None, 5408)              0
#
#  dense_16 (Dense)            (None, 512)               2769408
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_17 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 2,774,858
# Trainable params: 2,774,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
model.save('model.h5')

# %%
from keras.models import load_model

class Predictor:
    def __init__(self, model_path):
        self.model_path = model_path
        self.model = None
    
    def predict(self, image):
        # load the model from disk if it hasn't been loaded
        if self.model is None:
            self.model = load_model(self.model_path)
        
        # predict the image
        prediction = self.model.predict(image)
        
        # return the predicted label
        return np.argmax(prediction)

# %%
# select 10 random images from the test set
random_indices = np.random.randint(0, len(X_test), 10)
random_images = X_test[random_indices]
random_labels = y_test[random_indices]

predictor = Predictor("model.h5")

for i in range(10):
    predicted_label = predictor.predict(random_images[i].reshape(1,28,28,1))
    print("True Label: ", random_labels[i], "Predicted Label: ", predicted_label)
# Out:
# 1/1 [==============================] - 0s 77ms/step
# True Label:  9 Predicted Label:  9
# 1/1 [==============================] - 0s 15ms/step
# True Label:  1 Predicted Label:  1
# 1/1 [==============================] - 0s 19ms/step
# True Label:  5 Predicted Label:  5
# 1/1 [==============================] - 0s 19ms/step
# True Label:  2 Predicted Label:  2
# 1/1 [==============================] - 0s 24ms/step
# True Label:  8 Predicted Label:  8
# 1/1 [==============================] - 0s 17ms/step
# True Label:  2 Predicted Label:  2
# 1/1 [==============================] - 0s 17ms/step
# True Label:  7 Predicted Label:  7
# 1/1 [==============================] - 0s 18ms/step
# True Label:  9 Predicted Label:  9
# 1/1 [==============================] - 0s 18ms/step
# True Label:  9 Predicted Label:  9
# 1/1 [==============================] - 0s 17ms/step
# True Label:  9 Predicted Label:  9

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Predict the test set
y_pred = model.predict(X_test)

# Convert the predicted probabilities to class labels
y_pred = np.argmax(y_pred, axis=1)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 250/250 [==============================] - 1s 3ms/step
